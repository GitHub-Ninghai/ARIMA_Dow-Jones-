# %%
import pandas as pd
dif_data = 'dif_test.csv'
dif_data = pd.read_csv(dif_data, index_col=0, parse_dates=[0])
dif_data.head()
# Out:
#             values  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6
# data
# 2015-01-02    20.0         NaN         NaN         NaN         NaN         NaN
# 2015-01-05    60.0         NaN         NaN         NaN         NaN         NaN
# 2015-01-06   130.0         NaN         NaN         NaN         NaN         NaN
# 2015-01-07   150.0         NaN         NaN         NaN         NaN         NaN
# 2015-01-08   160.0         NaN         NaN         NaN         NaN         NaN

# %%
import matplotlib.pylab as plt
import seaborn as sns
dif_data.plot(figsize=(12,8))
plt.legend(bbox_to_anchor=(1.25, 0.5))
plt.title("method of difference")
sns.despine()

# %%
stock_diff = dif_data.diff()
stock_diff.plot(figsize=(9,5))
plt.legend(bbox_to_anchor=(1.25, 0.5))
plt.title("first difference")
sns.despine()
